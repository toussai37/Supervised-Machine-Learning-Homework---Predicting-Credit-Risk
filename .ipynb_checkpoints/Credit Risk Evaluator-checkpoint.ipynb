# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              50.0                   0.0        0.0         577150.0
# 1              33.3                   0.0        0.0         132750.0
# 2              33.3                   0.0        0.0         628160.0
# 3              16.7                   1.0        0.0          42006.0
# 4              66.7                   0.0        0.0         283248.0
#
#    total_bal_ex_mort  total_bc_limit total_il_high_credit_limit  \
# 0           122018.0         32000.0                   170200.0
# 1            27896.0         15900.0                    35398.0
# 2           114043.0         22600.0                    90340.0
# 3            20761.0         19900.0                    15406.0
# 4           109056.0         79500.0                    58778.0
#
#    hardship_flag  debt_settlement_flag
# 0              N                     N
# 1              N                     N
# 2              N                     N
# 3              N                     N
# 4              N                     N
#
# [5 rows x 86 columns]

# %%
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1       25429  25429     6000.0    0.1524       208.70           RENT
# 2       38496  38496     3600.0    0.1695       128.27           RENT
# 3       19667  19667    20000.0    0.1524       478.33           RENT
# 4       37505  37505     3600.0    0.1240       120.27           RENT
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    140000.0        Not Verified    low_risk          n  ...            97.7
# 1     55000.0        Not Verified    low_risk          n  ...            66.7
# 2     42000.0        Not Verified    low_risk          n  ...           100.0
# 3    100000.0        Not Verified    low_risk          n  ...           100.0
# 4     50000.0        Not Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         527975.0
# 1               0.0                   0.0        0.0          34628.0
# 2               0.0                   0.0        0.0          23100.0
# 3              50.0                   0.0        0.0          56481.0
# 4              25.0                   0.0        0.0          45977.0
#
#    total_bal_ex_mort  total_bc_limit total_il_high_credit_limit  \
# 0            70914.0         74600.0                    99475.0
# 1            23460.0          5900.0                    23628.0
# 2            19183.0          7300.0                    15000.0
# 3            43817.0         13800.0                    35981.0
# 4            32448.0         21000.0                    24977.0
#
#    hardship_flag  debt_settlement_flag
# 0              N                     N
# 1              N                     N
# 2              N                     N
# 3              N                     N
# 4              N                     N
#
# [5 rows x 86 columns]

# %%
a = train_df['home_ownership'].unique()
print(a)
# Out:
# ['MORTGAGE' 'RENT' 'OWN' 'ANY']

# %%
a = train_df['verification_status'].unique()
print(a)
# Out:
# ['Not Verified' 'Source Verified' 'Verified']

# %%
a = train_df['loan_status'].unique()
print(a)
# Out:
# ['low_risk' 'high_risk']

# %%
a = train_df['initial_list_status'].unique()
print(a)
# Out:
# ['w' 'f']

# %%
a = train_df['application_type'].unique()
print(a)
# Out:
# ['Individual' 'Joint App']

# %%
a = train_df['hardship_flag'].unique()
print(a)
# Out:
# ['N' 'Y']

# %%
a = train_df['debt_settlement_flag'].unique()
print(a)
# Out:
# ['N' 'Y']

# %%
a = test_df['debt_settlement_flag'].unique()
print(a)
# Out:
# ['N']

# %%
# Convert categorical data to numeric and separate target feature for training data
home_ownership_dict = {'MORTGAGE': 0, 'RENT': 1, 'OWN': 2, 'ANY': 3}
home_ownership_train_df = train_df.replace({'home_ownership': home_ownership_dict})
home_ownership_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              50.0                   0.0        0.0         577150.0
# 1              33.3                   0.0        0.0         132750.0
# 2              33.3                   0.0        0.0         628160.0
# 3              16.7                   1.0        0.0          42006.0
# 4              66.7                   0.0        0.0         283248.0
#
#    total_bal_ex_mort  total_bc_limit total_il_high_credit_limit  \
# 0           122018.0         32000.0                   170200.0
# 1            27896.0         15900.0                    35398.0
# 2           114043.0         22600.0                    90340.0
# 3            20761.0         19900.0                    15406.0
# 4           109056.0         79500.0                    58778.0
#
#    hardship_flag  debt_settlement_flag
# 0              N                     N
# 1              N                     N
# 2              N                     N
# 3              N                     N
# 4              N                     N
#
# [5 rows x 86 columns]

# %%
home_ownership_train_df['home_ownership'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
verification_status_dict = {'Not Verified': 0, 'Source Verified': 1, 'Verified': 2}
verification_status_train_df = home_ownership_train_df.replace({'verification_status': verification_status_dict})
verification_status_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status loan_status pymnt_plan  ...  \
# 0    223000.0                    0    low_risk          n  ...
# 1    123000.0                    1    low_risk          n  ...
# 2    197000.0                    1    low_risk          n  ...
# 3     45000.0                    0    low_risk          n  ...
# 4    133000.0                    1    low_risk          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#   total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                   170200.0              N                     N
# 1                    35398.0              N                     N
# 2                    90340.0              N                     N
# 3                    15406.0              N                     N
# 4                    58778.0              N                     N
#
# [5 rows x 86 columns]

# %%
verification_status_train_df['verification_status'].unique()
# Out:
# array([0, 1, 2])

# %%
loan_status_dict = {'low_risk': 0, 'high_risk': 1}
loan_status_train_df = verification_status_train_df.replace({'loan_status': loan_status_dict})
loan_status_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    223000.0                    0            0          n  ...
# 1    123000.0                    1            0          n  ...
# 2    197000.0                    1            0          n  ...
# 3     45000.0                    0            0          n  ...
# 4    133000.0                    1            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#   total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                   170200.0              N                     N
# 1                    35398.0              N                     N
# 2                    90340.0              N                     N
# 3                    15406.0              N                     N
# 4                    58778.0              N                     N
#
# [5 rows x 86 columns]

# %%
loan_status_train_df['loan_status'].unique()
# Out:
# array([0, 1])

# %%
initial_list_status_dict = {'w': 0, 'f': 1}
initial_list_status_train_df = loan_status_train_df.replace({'initial_list_status': initial_list_status_dict})
initial_list_status_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    223000.0                    0            0          n  ...
# 1    123000.0                    1            0          n  ...
# 2    197000.0                    1            0          n  ...
# 3     45000.0                    0            0          n  ...
# 4    133000.0                    1            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    170200.0              N                     N
# 1                     35398.0              N                     N
# 2                     90340.0              N                     N
# 3                     15406.0              N                     N
# 4                     58778.0              N                     N
#
# [5 rows x 86 columns]

# %%
initial_list_status_train_df['initial_list_status'].unique()
# Out:
# array([0, 1])

# %%
application_type_dict = {'Individual': 0, 'Joint App': 1}
application_type_train_df = initial_list_status_train_df.replace({'application_type': application_type_dict})
application_type_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    223000.0                    0            0          n  ...
# 1    123000.0                    1            0          n  ...
# 2    197000.0                    1            0          n  ...
# 3     45000.0                    0            0          n  ...
# 4    133000.0                    1            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    170200.0              N                     N
# 1                     35398.0              N                     N
# 2                     90340.0              N                     N
# 3                     15406.0              N                     N
# 4                     58778.0              N                     N
#
# [5 rows x 86 columns]

# %%
application_type_train_df['application_type'].unique()
# Out:
# array([0, 1])

# %%
hardship_flag_dict = {'N': 0, 'Y': 1}
hardship_flag_train_df = application_type_train_df.replace({'hardship_flag': hardship_flag_dict})
hardship_flag_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    223000.0                    0            0          n  ...
# 1    123000.0                    1            0          n  ...
# 2    197000.0                    1            0          n  ...
# 3     45000.0                    0            0          n  ...
# 4    133000.0                    1            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    170200.0              0                     N
# 1                     35398.0              0                     N
# 2                     90340.0              0                     N
# 3                     15406.0              0                     N
# 4                     58778.0              0                     N
#
# [5 rows x 86 columns]

# %%
hardship_flag_train_df['hardship_flag'].unique()
# Out:
# array([0, 1])

# %%
debt_settlement_flag_dict = {'N': 0, 'Y': 1}
debt_settlement_flag_train_df = hardship_flag_train_df.replace({'debt_settlement_flag': debt_settlement_flag_dict})
debt_settlement_flag_train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34               0
# 1      141451  141451    21000.0    0.1308       478.68               0
# 2      321143  321143    20000.0    0.1240       448.95               0
# 3       11778   11778     3000.0    0.1240       100.22               1
# 4      169382  169382    30000.0    0.1612      1056.49               0
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    223000.0                    0            0          n  ...
# 1    123000.0                    1            0          n  ...
# 2    197000.0                    1            0          n  ...
# 3     45000.0                    0            0          n  ...
# 4    133000.0                    1            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0           100.0              50.0                   0.0        0.0
# 1            85.0              33.3                   0.0        0.0
# 2            85.7              33.3                   0.0        0.0
# 3           100.0              16.7                   1.0        0.0
# 4           100.0              66.7                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    170200.0              0                     0
# 1                     35398.0              0                     0
# 2                     90340.0              0                     0
# 3                     15406.0              0                     0
# 4                     58778.0              0                     0
#
# [5 rows x 86 columns]

# %%
debt_settlement_flag_train_df['debt_settlement_flag'].unique()
# Out:
# array([0, 1])

# %%
# Convert categorical data to numeric and separate target feature for testing data
home_ownership_dict = {'MORTGAGE': 0, 'RENT': 1, 'OWN': 2, 'ANY': 3}
home_ownership_test_df = test_df.replace({'home_ownership': home_ownership_dict})
home_ownership_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    140000.0        Not Verified    low_risk          n  ...            97.7
# 1     55000.0        Not Verified    low_risk          n  ...            66.7
# 2     42000.0        Not Verified    low_risk          n  ...           100.0
# 3    100000.0        Not Verified    low_risk          n  ...           100.0
# 4     50000.0        Not Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         527975.0
# 1               0.0                   0.0        0.0          34628.0
# 2               0.0                   0.0        0.0          23100.0
# 3              50.0                   0.0        0.0          56481.0
# 4              25.0                   0.0        0.0          45977.0
#
#    total_bal_ex_mort  total_bc_limit total_il_high_credit_limit  \
# 0            70914.0         74600.0                    99475.0
# 1            23460.0          5900.0                    23628.0
# 2            19183.0          7300.0                    15000.0
# 3            43817.0         13800.0                    35981.0
# 4            32448.0         21000.0                    24977.0
#
#    hardship_flag  debt_settlement_flag
# 0              N                     N
# 1              N                     N
# 2              N                     N
# 3              N                     N
# 4              N                     N
#
# [5 rows x 86 columns]

# %%
home_ownership_test_df['home_ownership'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
verification_status_dict = {'Not Verified': 0, 'Source Verified': 1, 'Verified': 2}
verification_status_test_df = home_ownership_test_df.replace({'verification_status': verification_status_dict})
verification_status_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status loan_status pymnt_plan  ...  \
# 0    140000.0                    0    low_risk          n  ...
# 1     55000.0                    0    low_risk          n  ...
# 2     42000.0                    0    low_risk          n  ...
# 3    100000.0                    0    low_risk          n  ...
# 4     50000.0                    0    low_risk          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#   total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    99475.0              N                     N
# 1                    23628.0              N                     N
# 2                    15000.0              N                     N
# 3                    35981.0              N                     N
# 4                    24977.0              N                     N
#
# [5 rows x 86 columns]

# %%
verification_status_test_df['verification_status'].unique()
# Out:
# array([0, 2, 1])

# %%
loan_status_dict = {'low_risk': 0, 'high_risk': 1}
loan_status_test_df = verification_status_test_df.replace({'loan_status': loan_status_dict})
loan_status_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            0          n  ...
# 1     55000.0                    0            0          n  ...
# 2     42000.0                    0            0          n  ...
# 3    100000.0                    0            0          n  ...
# 4     50000.0                    0            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#   total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    99475.0              N                     N
# 1                    23628.0              N                     N
# 2                    15000.0              N                     N
# 3                    35981.0              N                     N
# 4                    24977.0              N                     N
#
# [5 rows x 86 columns]

# %%
loan_status_test_df['loan_status'].unique()
# Out:
# array([0, 1])

# %%
initial_list_status_dict = {'w': 0, 'f': 1}
initial_list_status_test_df = loan_status_test_df.replace({'initial_list_status': initial_list_status_dict})
initial_list_status_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            0          n  ...
# 1     55000.0                    0            0          n  ...
# 2     42000.0                    0            0          n  ...
# 3    100000.0                    0            0          n  ...
# 4     50000.0                    0            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     99475.0              N                     N
# 1                     23628.0              N                     N
# 2                     15000.0              N                     N
# 3                     35981.0              N                     N
# 4                     24977.0              N                     N
#
# [5 rows x 86 columns]

# %%
initial_list_status_test_df['initial_list_status'].unique()
# Out:
# array([0, 1])

# %%
application_type_dict = {'Individual': 0, 'Joint App': 1}
application_type_test_df = initial_list_status_test_df.replace({'application_type': application_type_dict})
application_type_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            0          n  ...
# 1     55000.0                    0            0          n  ...
# 2     42000.0                    0            0          n  ...
# 3    100000.0                    0            0          n  ...
# 4     50000.0                    0            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     99475.0              N                     N
# 1                     23628.0              N                     N
# 2                     15000.0              N                     N
# 3                     35981.0              N                     N
# 4                     24977.0              N                     N
#
# [5 rows x 86 columns]

# %%
application_type_test_df['application_type'].unique()
# Out:
# array([0, 1])

# %%
hardship_flag_dict = {'N': 0, 'Y': 1}
hardship_flag_test_df = application_type_test_df.replace({'hardship_flag': hardship_flag_dict})
hardship_flag_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            0          n  ...
# 1     55000.0                    0            0          n  ...
# 2     42000.0                    0            0          n  ...
# 3    100000.0                    0            0          n  ...
# 4     50000.0                    0            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     99475.0              0                     N
# 1                     23628.0              0                     N
# 2                     15000.0              0                     N
# 3                     35981.0              0                     N
# 4                     24977.0              0                     N
#
# [5 rows x 86 columns]

# %%
hardship_flag_test_df['hardship_flag'].unique()
# Out:
# array([0, 1])

# %%
debt_settlement_flag_dict = {'N': 0, 'Y': 1}
debt_settlement_flag_test_df = hardship_flag_test_df.replace({'debt_settlement_flag': debt_settlement_flag_dict})
debt_settlement_flag_test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70               0
# 1       25429  25429     6000.0    0.1524       208.70               1
# 2       38496  38496     3600.0    0.1695       128.27               1
# 3       19667  19667    20000.0    0.1524       478.33               1
# 4       37505  37505     3600.0    0.1240       120.27               1
#
#    annual_inc  verification_status  loan_status pymnt_plan  ...  \
# 0    140000.0                    0            0          n  ...
# 1     55000.0                    0            0          n  ...
# 2     42000.0                    0            0          n  ...
# 3    100000.0                    0            0          n  ...
# 4     50000.0                    0            0          n  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# 1            66.7               0.0                   0.0        0.0
# 2           100.0               0.0                   0.0        0.0
# 3           100.0              50.0                   0.0        0.0
# 4           100.0              25.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     99475.0              0                     0
# 1                     23628.0              0                     0
# 2                     15000.0              0                     0
# 3                     35981.0              0                     0
# 4                     24977.0              0                     0
#
# [5 rows x 86 columns]

# %%
debt_settlement_flag_test_df['debt_settlement_flag'].unique()
# Out:
# array([0])

# %%
clean_test_df = debt_settlement_flag_test_df.drop(columns=['Unnamed: 0','index','pymnt_plan' ])

# %%
clean_train_df = debt_settlement_flag_train_df.drop(columns=['Unnamed: 0','index','pymnt_plan' ])

# %%
X = clean_train_df.drop('loan_status', axis=1)
X
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# 0        13375.0    0.1797       483.34               0    223000.0
# 1        21000.0    0.1308       478.68               0    123000.0
# 2        20000.0    0.1240       448.95               0    197000.0
# 3         3000.0    0.1240       100.22               1     45000.0
# 4        30000.0    0.1612      1056.49               0    133000.0
# ...          ...       ...          ...             ...         ...
# 12175    19975.0    0.2565       801.09               1     28000.0
# 12176    15000.0    0.1774       540.34               1     50000.0
# 12177     3600.0    0.1862       131.28               1     60000.0
# 12178    15000.0    0.0881       475.68               0     62000.0
# 12179    15000.0    0.1774       540.34               1     54080.0
#
#        verification_status    dti  delinq_2yrs  inq_last_6mths  open_acc  ...  \
# 0                        0  29.99          0.0             0.0      15.0  ...
# 1                        1  11.26          2.0             0.0      16.0  ...
# 2                        1  11.28          0.0             0.0      12.0  ...
# 3                        0  18.08          0.0             0.0      12.0  ...
# 4                        1  27.77          0.0             2.0      13.0  ...
# ...                    ...    ...          ...             ...       ...  ...
# 12175                    0  28.42          0.0             0.0      15.0  ...
# 12176                    2  23.43          4.0             0.0      16.0  ...
# 12177                    0  28.80          0.0             1.0      14.0  ...
# 12178                    1  11.44          0.0             0.0       5.0  ...
# 12179                    0  21.66          1.0             1.0       5.0  ...
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0               100.0              50.0                   0.0        0.0
# 1                85.0              33.3                   0.0        0.0
# 2                85.7              33.3                   0.0        0.0
# 3               100.0              16.7                   1.0        0.0
# 4               100.0              66.7                   0.0        0.0
# ...               ...               ...                   ...        ...
# 12175           100.0              16.7                   0.0        0.0
# 12176            90.5              11.1                   0.0        0.0
# 12177           100.0               0.0                   0.0        0.0
# 12178           100.0               0.0                   0.0        0.0
# 12179            90.0             100.0                   0.0        0.0
#
#        tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0             577150.0           122018.0         32000.0
# 1             132750.0            27896.0         15900.0
# 2             628160.0           114043.0         22600.0
# 3              42006.0            20761.0         19900.0
# 4             283248.0           109056.0         79500.0
# ...                ...                ...             ...
# 12175          50055.0            28192.0         18700.0
# 12176          70324.0            57025.0         13300.0
# 12177          83765.0            55156.0         14800.0
# 12178         189930.0            23748.0          7000.0
# 12179          48968.0            29786.0          2900.0
#
#        total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                        170200.0              0                     0
# 1                         35398.0              0                     0
# 2                         90340.0              0                     0
# 3                         15406.0              0                     0
# 4                         58778.0              0                     0
# ...                           ...            ...                   ...
# 12175                     19055.0              0                     0
# 12176                     54824.0              0                     0
# 12177                     53065.0              0                     0
# 12178                     32930.0              0                     0
# 12179                     33968.0              0                     0
#
# [12180 rows x 82 columns]

# %%
y_label = LabelEncoder().fit_transform(clean_train_df['loan_status'])
y_label
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
# add missing dummy variables to testing set
train_objs_num = len(clean_train_df)
dataset = pd.concat(objs=[clean_train_df, clean_test_df], axis=0)
dataset_preprocessed = pd.get_dummies(dataset)
train_preprocessed = dataset_preprocessed[:train_objs_num]
test_preprocessed = dataset_preprocessed[train_objs_num:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_label, random_state=1)

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6526546250684182
# Testing Data Score: 0.6476190476190476
# /Users/alain/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
